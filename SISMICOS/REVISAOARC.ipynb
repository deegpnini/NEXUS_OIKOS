# %% [markdown]
# # REVISAOARC.ipynb
#
# Arquivo pendente de sincronização.
#
# **Instruções:**
# 1. Abra o Colab
# 2. Vá em 'Recentes'
# 3. Abra este notebook
# 4. Arquivo → Baixar .ipynb
# 5. Salve em: SISMICOS/
